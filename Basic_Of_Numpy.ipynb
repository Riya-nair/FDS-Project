# %%
import numpy as np
dataset=[21,11,19,18,29,46,20]
variance=np.var(dataset)
print("With numpy method=",variance)
# Out:
# With numpy method= 108.81632653061224

# %%
import statistics
dataset=[21,19,11,21,19,46,29]
output= statistics.variance(dataset)
print("With 1 arg=",output)
meanvalue= statistics.mean(dataset)
output1= statistics.variance(dataset,meanvalue)
print("With 2 arg=",output1)

# %%
import matplotlib.pyplot as plt 
x = [i for i in range(10)]
y = [i for i in range(10)] 
plt.figure(figsize = (5,5)) 
plt.xlabel('X-axis') 
plt.ylabel('Y-axis') 
plt.title('My First Plot') 
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [11,12,13,14,15]
y= [11,12,13,14,15]
plt.figure(figsize=(6,6)) 
plt.xlim(0,6)
plt.ylim(0,6) 
plt.subplot(1,2,2) 
plt.title('sub plot1')
plt.plot(x,y,'--b') 
plt.subplot(2,2,1) 
plt.title('sub plot2') 
plt.plot(x,y,'og') 
plt.grid() 
plt.show()

# %%
import matplotlib.pyplot as plt 
lst1=[11,12,13,14]
lst2=[21,22,23,24]
plt.plot(lst1,lst2)
plt.show()

# %%
x=[100,-200,300,400,900];
y=[500,-600,700,-800,1000];
plt.plot(x,np.sin(x),color="Purple")
plt.plot(y,np.cos(y),color="Green")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph")
plt.plot(x,y)
plt.legend("Linear")
plt.show()

# %%
x=[1,2,3,4];
y=[10,11,12,10];
z=plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph")
plt.plot(x,y)
plt.legend("Linear")
plt.show()

# %%
x=[1,2,3,4];
y=[10,11,12,10];
z=plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph")
plt.plot(x,y)
plt.legend("Linear")
plt.show()

# %%
x=[1,2,3,4];
y=[10,11,12,10];
z=plt.bar(x,y)
plt.title("Graph")
plt.legend("Linear")
plt.show()

# %%
x=[1,2,3,4];
y=[10,11,12,10];
z=plt.barh(x,y)
plt.title("Graph")
plt.legend("Linear")
plt.show()

# %%
domain=['Man','Boy','Girl','Transgender']
count=[11,12,15,16]
plt.pie(count,labels=domain,shadow=True,startangle=50)
plt.legend(title="domain lists")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
plt.style.use('classic')
data =np.random.randn(600) 
#print(data)
plt.hist(data)
# Out:
# (array([ 12.,  34.,  77., 111., 151., 117.,  67.,  21.,   9.,   1.]),
#  array([-2.82989466, -2.19891844, -1.56794222, -0.936966  , -0.30598977,
#          0.32498645,  0.95596267,  1.58693889,  2.21791511,  2.84889134,
#          3.47986756]),
#  <a list of 10 Patch objects>)

# %%
# Import pandas package
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
 
# select two columns
print(df[['Name', 'Qualification']])

# %%
domain = ['Dsd', 'network', 'python', 'java']
count=[10,5, 7,13]
#plt.bar(domain, count) #plt.barh(domain, count) #plt.scatter(domain, count)
plt.pie(count, labels=domain, shadow = True, startangle=45) 
plt.legend(title = 'domain lists')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
plt.style.use('classic')
data = np.random.randn(100) 
#print(data)
plt.hist(data)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,20)
print(x)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()
# Out:
# [ 0.          0.40816327  0.81632653  1.2244898   1.63265306  2.04081633
#   2.44897959  2.85714286  3.26530612  3.67346939  4.08163265  4.48979592
#   4.89795918  5.30612245  5.71428571  6.12244898  6.53061224  6.93877551
#   7.34693878  7.75510204  8.16326531  8.57142857  8.97959184  9.3877551
#   9.79591837 10.20408163 10.6122449  11.02040816 11.42857143 11.83673469
#  12.24489796 12.65306122 13.06122449 13.46938776 13.87755102 14.28571429
#  14.69387755 15.10204082 15.51020408 15.91836735 16.32653061 16.73469388
#  17.14285714 17.55102041 17.95918367 18.36734694 18.7755102  19.18367347
#  19.59183673 20.        ]

# %%
import numpy as np
import matplotlib.pyplot as plt 
x = np.linspace(1,5,20)
def normal_dist(x, mean,sd):
  prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2) 
  return prob_density
mean = np.mean(x) 
sd = np.std(x)
pdf = normal_dist(x, mean, sd)
plt.plot(x,pdf, color = 'red') 
plt.xlabel('Data Points') 
plt.ylabel('Probility Density')
# Out:
# Text(0, 0.5, 'Probility Density')

# %%
import numpy as np
a = np.array([[11,2, 4], [5, 8, 7]], dtype = 'float') 
print ("Array created using passed list:\n", a)
b = np.array((11 , 3, 2))
print ("\nArray created using passed tuple:\n", b)
c = np.zeros((3, 4))
print ("\nAn array initialized with all zeros:\n", c)
d = np.full((3, 3), 6, dtype = 'complex')
print ("\nAn array initialized with all 6s." "Array type is complex:\n", d)
e = np.random.random((2, 2))
print ("\nA random array:\n", e)
f = np.arange(0, 30, 5)
print ("\nA sequential array with steps of 5:\n", f)
g = np.linspace(0, 5, 10)
print ("\nA sequential array with 10 values between"
"0 and 5:\n", g)
arr = np.array([[1, 2, 3, 4],
[5, 2, 4, 2],
[1, 2, 0, 1]])
newarr = arr.reshape(2, 2, 3)
print ("\nOriginal array:\n", arr) 
print ("Reshaped array:\n", newarr)
arr = np.array([[1, 2, 3], [4, 5, 6]]) 
flarr = arr.flatten()
print ("\nOriginal array:\n", arr)
print ("Fattened array:\n", flarr)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x = np.array([150,200,250,400,500,600]).reshape((-1,1))
y = np.array([500,550,640,750,800,850])
plt.scatter(x,y)
model = LinearRegression().fit(x,y) 
r_sq = model.score(x,y)
print('coefficient of determination:',r_sq) 
print('intercept:',model.intercept_) 
print('slope:',model.coef_)
y_pred = model.predict(x) 
print('predicted responce',y_pred,sep='\n') 
plt.plot(x,y_pred)
# Out:
# coefficient of determination: 0.9620847350714886
# intercept: 411.51041666666646
# slope: [0.771875]
# predicted responce
# [527.29166667 565.88541667 604.47916667 720.26041667 797.44791667
#  874.63541667]

# %%
import matplotlib.pyplot as plt 
x = [1,2,3,4,5]
y= [0,1,2,3,4] 
plt.subplot(1,2,1) 
plt.title('sub plot1') 
plt.plot(x,y,'--b') 
plt.subplot(1,2,2) 
plt.title('sub plot2') 
plt.plot(x,y,'og') 
plt.grid() 
plt.show()

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as np
# %matplotlib inline

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-74122432-548a-4fa2-a625-541a09b6d6f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74122432-548a-4fa2-a625-541a09b6d6f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Sample Excel(1).xlsx to Sample Excel(1) (1).xlsx

# %%
df2=pd.read_excel('Sample Excel(1).xlsx')
df2.head()
# Out:
#     X   Y
# 0  12  21
# 1  10  22
# 2  13  23
# 3  15  24

# %%
df2.corr()
# Out:
#           X         Y
# X  1.000000  0.744208
# Y  0.744208  1.000000

# %%
variable1 = df2['X'] 
variable2 = df2['Y']
variable1.corr(variable2)
df2.corr()
# Out:
#           X         Y
# X  1.000000  0.744208
# Y  0.744208  1.000000

# %%
plt.scatter(variable1, variable2, color='PURPLE')

# %%
sns.pairplot(df2) 
sns.heatmap(df2.corr())

# %%
variable1 = df2['X'] 
variable2 = df2['Y']
variable1.corr(variable2)
df2.corr() 
print(np.corr(variable1, variable2))

# %%
X= variable1 
Y = variable2
print(sp.pearsonr(variable1, variable2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-48f4aff50f78> in <module>()
#       1 X= variable1
#       2 Y = variable2
# ----> 3 print(sp.pearsonr(variable1, variable2))
#
# NameError: name 'sp' is not defined

# %%
plt.scatter(variable1,variable2,color='green')

# %% [markdown]
# Second Note Book

# %%
x=[1,2,3,4,5]
y=[6,7,8,9,10]
z=[9,8,7,6,5]
plt.scatter(x,y,color='Red')
plt.scatter(x,z,color='Green')

# %%
plt.scatter(x,z,color='Green')

# %%
x=np.random.randn(100)
y1=x*5+10
y2=-5*x
y3=np.random.randn(100)
plt.scatter(x,y1,label=f'y1 Correlation ={np.round(np.corrcoef(x,y1)[1,0], 3)}')
plt.scatter(x,y2,label=f'y2 Correlation ={np.round(np.corrcoef(x,y2)[1,0], 3)}')
plt.scatter(x,y3,label=f'y3 Correlation ={np.round(np.corrcoef(x,y3)[1,0], 3)}')
plt.title('Scatterplot and Correlation')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
titanic_train = pd.read_csv("train.csv") # Read the data
char_cabin = titanic_train["Cabin"].astype(str) # Convert cabin to str
new_Cabin = np.array([cabin[0] for cabin in char_cabin]) # Take first letter
titanic_train["Cabin"] = pd.Categorical(new_Cabin) # Save the new cabin var
my_tab = pd.crosstab(index=titanic_train["Survived"],columns="count")
my_tab
type(my_tab)
pd.crosstab(index=titanic_train["Pclass"],columns="count")
pd.crosstab(index=titanic_train["Sex"],columns="count")
cabin_tab = pd.crosstab(index=titanic_train["Cabin"],
columns="count")
cabin_tab
titanic_train.Sex.value_counts()
print (cabin_tab.sum(), "\n") # Sum the counts
print (cabin_tab.shape, "\n") # Check number of rows and cols
cabin_tab.iloc[1:7] # Slice
cabin_tab/cabin_tab.sum()

# %%
# !apt-get install -q libgeos-3.5.0
# !apt-get install -q libgeos-dev
# !pip install -q https://github.com/matplotlib/basemap/archive/master.zip
# !pip install -q pyproj==1.9.6
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# E: Unable to locate package libgeos-3.5.0
# E: Couldn't find any package by glob 'libgeos-3.5.0'
# E: Couldn't find any package by regex 'libgeos-3.5.0'
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libgeos-dev is already the newest version (3.6.2-1build2).
# libgeos-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
#      |████████████████████████████████| 133.1 MB 25 kB/s
#      |████████████████████████████████| 6.3 MB 7.0 MB/s
#      |████████████████████████████████| 219 kB 28.9 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 6.8 MB/s
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
fig = plt.figure(figsize=(6, 6))
m = Basemap(projection='lcc', resolution=None,width=8E6, height=8E6,lat_0=45, lon_0=-100,)
m.etopo(scale=0.4, alpha=0.4)
# Map (long, lat) to (x, y) for plotting
x, y = m(-122.3, 47.6)
plt.plot(x, y, 'ok', markersize=7)
plt.text(x, y, ' Seattle', fontsize=10);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None,
lat_0=50, lon_0=0)
draw_map(m);

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None,lon_0=0, lat_0=50, lat_1=45, lat_2=55,width=1.6E7, height=1.2E7)
draw_map(m)

# %%
from itertools import chain
def draw_map(m, scale=0.2):
  # draw a shaded-relief image
  m.shadedrelief(scale=scale)
  # lats and longs are returned as a dictionary
  lats = m.drawparallels(np.linspace(-90, 90, 13))
  lons = m.drawmeridians(np.linspace(-180, 180, 13))
  # keys contain the plt.Line2D instances
  lat_lines = chain(*(tup[1][0] for tup in lats.items()))
  lon_lines = chain(*(tup[1][0] for tup in lons.items()))
  all_lines = chain(lat_lines, lon_lines)
  # cycle through these lines and set the desired style
  for line in all_lines:
    line.set(linestyle='-', alpha=0.3, color='w')

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution=None,llcrnrlat=-90, urcrnrlat=90,llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)

fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cea', resolution=None,llcrnrlat=-90, urcrnrlat=90,llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)

# %%
x=np.random.randn(100)
y1=x*5+10
y2=-5*x
y3=np.random.randn(100)
plt.scatter(x,y1,label=f'y1 Correlation ={np.round(np.corrcoef(x,y1)[1,0], 3)}')
plt.scatter(x,y2,label=f'y2 Correlation ={np.round(np.corrcoef(x,y2)[1,0], 3)}')
plt.scatter(x,y3,label=f'y3 Correlation ={np.round(np.corrcoef(x,y3)[1,0], 3)}')
plt.scatter(x,y1,color='Red')
plt.scatter(x,y2,color='Green')
plt.scatter(x,y3,color='Blue')
plt.title('Scatterplot and Correlation')
plt.legend()
plt.show()

# %% [markdown]
# # New Section
